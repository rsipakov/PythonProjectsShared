# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
SO2_df = pd.read_excel('/Users/ross/Dropbox (Personal)/Education/KNUBA/KNUBA_PhD_Sipakov/Tableau/post_20_Kyiv.xls', engine='xlrd')

# %%
SO2_df .head()
# Out:
#       SO2     NO2      NO    CH2O
# 0  0.0184  0.0368  0.0258  0.0018
# 1  0.0214  0.0735  0.0414  0.0039
# 2  0.0463  0.1530  0.0898  0.0062
# 3  0.0517  0.1629  0.0947  0.0026
# 4  0.0138  0.0494  0.0380  0.0015

# %%
#Using the correlation method
sns.heatmap(SO2_df.corr())
# Out:
# <AxesSubplot:>

# %%
plt.savefig('saving-a-seaborn-plot-as-png-file-transparent.png', transparent=True)

# %%
sns.scatterplot(x='SO2', y='CH2O', data=SO2_df)
# Out:
# <AxesSubplot:xlabel='SO2', ylabel='CH2O'>

# %%
plt.savefig('saving-a-seaborn-plot-as-pdf-file.pdf')

# %%
sns.scatterplot(x='SO2', y='CH2O', data=SO2_df)
plt.savefig('saving-a-seaborn-plot-as-pdf-file.pdf')

# %%
sns.heatmap(SO2_df.corr())
plt.savefig('saving-a-seaborn-plot-as-pdf-file.pdf')

# %%
sns.heatmap(SO2_df.corr())
plt.savefig('saving-a-seaborn-plot-as-png-file-transparent.png', transparent=True)

# %%
correlations = SO2_df.corr()

# %%
SO2_df.corr()
# Out:
#            SO2       NO2        NO      CH2O
# SO2   1.000000  0.516845  0.657316  0.365689
# NO2   0.516845  1.000000  0.816463  0.686926
# NO    0.657316  0.816463  1.000000  0.626236
# CH2O  0.365689  0.686926  0.626236  1.000000

# %%
SO2_df.corr()
# Out:
#            SO2       NO2        NO      CH2O
# SO2   1.000000  0.516845  0.657316  0.365689
# NO2   0.516845  1.000000  0.816463  0.686926
# NO    0.657316  0.816463  1.000000  0.626236
# CH2O  0.365689  0.686926  0.626236  1.000000

# %%
df1 = SO2_df.corr()
df1.to_excel("output.xlsx")

# %%
#always remember your magic function if using Jupyter
# %matplotlib inline
sns.heatmap(correlations)
plt.show()

# %%
import numpy as np

# %%
X1 = np.array([[0.6424,0.2615,0.1083], [0.8419,0.4061,0.0343], [0.8166,0.4554,0.1185], [0.7306,0.5805,0.0691]])

# %%
rank = np.linalg.matrix_rank(X1)

# %%
print('Matrix : ', X1)
# Out:
# Matrix :  [[0.6424 0.2615 0.1083]
#  [0.8419 0.4061 0.0343]
#  [0.8166 0.4554 0.1185]
#  [0.7306 0.5805 0.0691]]

# %%
print('Rank of the given Matrix : ',rank)
# Out:
# Rank of the given Matrix :  3
